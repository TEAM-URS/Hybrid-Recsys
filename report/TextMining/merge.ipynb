# %%
## 해당 경로에 있는 .csv 파일명 리스트 가져오기

import os

path = 'C:\\Coding\\Workspace\\UOUCapstionDesignTeam\\crawling\\kakao_google_crawling\\kakao_reviews\\restaruant\\reiview\\review_1'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.csv')] ## 파일명 끝이 .csv인 경우

# %%
## csv 파일들을 DataFrame으로 불러와서 concat
import pandas as pd

df = pd.DataFrame()
for i in file_list_py:
    data = pd.read_csv(path +'/'+ i)
    df = pd.concat([df,data])
    
df = df.reset_index(drop = True)

# %%
df
# Out:
#        place_id      user_id  score  \
# 0     225토마토스트릿           cu    5.0
# 1     225토마토스트릿          냠념뇸    4.0
# 2     225토마토스트릿           김영    2.0
# 3     225토마토스트릿         애니비아    2.0
# 4     225토마토스트릿        라떼처돌이    5.0
# ...         ...          ...    ...
# 4788  황장군 본사직영점            큐    1.0
# 4789  황장군 본사직영점           초호    1.0
# 4790  황장군 본사직영점  Boink (김봉균)    4.0
# 4791  황장군 본사직영점            J    4.0
# 4792  황장군 본사직영점          마이티    1.0
#
#                                                 comment
# 0               분위기가 진짜 미쳤습니다. 외부와 단절된 느낌으로다가 아늑하고 좋아요.
# 1     코스로 먹었습니다. 초반 에피타이져는 굉장히 맛있었는데 파스타가 너무 짜서 뒤에 스...
# 2     너무 어둡고 밀폐된 공간에 벨을 누르고 문 열어주면 입장에 허걱.카프레제 샐러드는 ...
# 3     일단 특이하게 벨 누르는? 인테리어도 특이하고 이런 식당이 많이 없으니까 신기하긴 ...
# 4       다 맛있음! 뭘 시켜도 맛있을 것같음.양이 보기보다 많아 배에 차곡차곡 쌓이는 느낌.
# ...                                                 ...
# 4788                                            남직원 불친절
# 4789                                            주인완전불친절
# ...

# %%
len(df['place_id'].unique())
# Out:
# 294

# %%
## 해당 경로에 있는 .csv 파일명 리스트 가져오기

import os

path = 'C:\\Coding\\Workspace\\UOUCapstionDesignTeam\\crawling\\kakao_google_crawling\\kakao_reviews\\restaruant\\reiview\\review_2'
file_list_2 = os.listdir(path)
file_list_py_2 = [file for file in file_list_2 if file.endswith('.csv')] ## 파일명 끝이 .csv인 경우

# %%
## csv 파일들을 DataFrame으로 불러와서 concat
import pandas as pd

df2 = pd.DataFrame()
for i in file_list_py_2:
    data = pd.read_csv(path +'/'+ i)
    df2 = pd.concat([df2,data])
    
df2 = df2.reset_index(drop = True)

# %%
len(df2['place_id'].unique())
# Out:
# 196

# %%
data_df = pd.concat([df, df2])
data_df
# Out:
#        place_id user_id  score  \
# 0     225토마토스트릿      cu    5.0
# 1     225토마토스트릿     냠념뇸    4.0
# 2     225토마토스트릿      김영    2.0
# 3     225토마토스트릿    애니비아    2.0
# 4     225토마토스트릿   라떼처돌이    5.0
# ...         ...     ...    ...
# 1655       효정밥상     조현철    3.0
# 1656       효정밥상  맛집 방랑자    4.0
# 1657       효정밥상     문영수    5.0
# 1658       효정밥상    바디걸즈    3.0
# 1659       효정밥상    포동포동    5.0
#
#                                                 comment
# 0               분위기가 진짜 미쳤습니다. 외부와 단절된 느낌으로다가 아늑하고 좋아요.
# 1     코스로 먹었습니다. 초반 에피타이져는 굉장히 맛있었는데 파스타가 너무 짜서 뒤에 스...
# 2     너무 어둡고 밀폐된 공간에 벨을 누르고 문 열어주면 입장에 허걱.카프레제 샐러드는 ...
# 3     일단 특이하게 벨 누르는? 인테리어도 특이하고 이런 식당이 많이 없으니까 신기하긴 ...
# 4       다 맛있음! 뭘 시켜도 맛있을 것같음.양이 보기보다 많아 배에 차곡차곡 쌓이는 느낌.
# ...                                                 ...
# 1655                                                NaN
# 1656                                 게장정식 양 푸짐하고 맛도 좋아요
# 1657                                          가격대비 갑입니다
# ...

# %%
data_df.to_csv('ulsan_rest_review.csv', index = False, encoding='utf-8-sig')

# %%
## 해당 경로에 있는 .csv 파일명 리스트 가져오기

import os
import natsort
path = '/Dais_internship/CZ/UOUCapstionDesignTeam/crawling/review_list'
file_list_py = natsort.natsorted(os.listdir('/Dais_internship/CZ/UOUCapstionDesignTeam/crawling/review_list'))

# %%
## csv 파일들을 DataFrame으로 불러와서 concat
import pandas as pd

df = pd.DataFrame()
for i in file_list_py:
    data = pd.read_csv(path +'/'+ i)
    df = pd.concat([df,data])
    
df = df.reset_index(drop = True)

# %%
df
# Out:
#           title  rate     tags                         address  \
# 0       산주막 삼산점   5.0  호프,요리주점    울산 남구 남중로80번길 26 1층 (우)44712
# 1    상무초밥 울산삼산점   4.0     초밥,롤     울산 남구 삼산로 270 101호 (우)44719
# 2          디오미오   3.8       양식   울산 남구 거마로104번길 25 1층 (우)44651
# 3          카페몽떼   3.9       카페  울산 울주군 온산읍 강양길 148 2층 (우)45008
# 4           세비로   2.8       카페       울산 남구 왕생로45번길 17 (우)44718
# ..          ...   ...      ...                             ...
# 530       라메르판지   3.9       카페    울산 북구 판지1길 30 1, 2층 (우)44233
# 531    육장장이 울산점   4.7    육류,고기    울산 남구 삼산중로84번길 11-5 (우)44705
# 532         돋질로   3.1      한정식      울산 남구 문수로327번길 14 (우)44645
# 533       행루즈버거   4.3      햄버거   울산 남구 월평로187번길 14 1층 (우)44696
# 534   등뼈가 울산달동점   4.6      감자탕           울산 남구 신정로 52 (우)44694
#
#                                         url
# 0     https://place.map.kakao.com/712292213
# 1      https://place.map.kakao.com/30184440
# 2    https://place.map.kakao.com/1467456839
# ...

# %%
df.reset_index(inplace=True)
# colume rename
df.rename(columns={'Unnamed: 0':'p_id'}, inplace=True)
df
# Out:
#      index       title  rate     tags                         address  \
# 0        0     산주막 삼산점   5.0  호프,요리주점    울산 남구 남중로80번길 26 1층 (우)44712
# 1        1  상무초밥 울산삼산점   4.0     초밥,롤     울산 남구 삼산로 270 101호 (우)44719
# 2        2        디오미오   3.8       양식   울산 남구 거마로104번길 25 1층 (우)44651
# 3        3        카페몽떼   3.9       카페  울산 울주군 온산읍 강양길 148 2층 (우)45008
# 4        4         세비로   2.8       카페       울산 남구 왕생로45번길 17 (우)44718
# ..     ...         ...   ...      ...                             ...
# 530    530       라메르판지   3.9       카페    울산 북구 판지1길 30 1, 2층 (우)44233
# 531    531    육장장이 울산점   4.7    육류,고기    울산 남구 삼산중로84번길 11-5 (우)44705
# 532    532         돋질로   3.1      한정식      울산 남구 문수로327번길 14 (우)44645
# 533    533       행루즈버거   4.3      햄버거   울산 남구 월평로187번길 14 1층 (우)44696
# 534    534   등뼈가 울산달동점   4.6      감자탕           울산 남구 신정로 52 (우)44694
#
#                                         url
# 0     https://place.map.kakao.com/712292213
# ...

# %%
df.rename(columns={'index':'p_id'}, inplace=True)
df
# Out:
#      p_id       title  rate     tags                         address  \
# 0       0     산주막 삼산점   5.0  호프,요리주점    울산 남구 남중로80번길 26 1층 (우)44712
# 1       1  상무초밥 울산삼산점   4.0     초밥,롤     울산 남구 삼산로 270 101호 (우)44719
# 2       2        디오미오   3.8       양식   울산 남구 거마로104번길 25 1층 (우)44651
# 3       3        카페몽떼   3.9       카페  울산 울주군 온산읍 강양길 148 2층 (우)45008
# 4       4         세비로   2.8       카페       울산 남구 왕생로45번길 17 (우)44718
# ..    ...         ...   ...      ...                             ...
# 530   530       라메르판지   3.9       카페    울산 북구 판지1길 30 1, 2층 (우)44233
# 531   531    육장장이 울산점   4.7    육류,고기    울산 남구 삼산중로84번길 11-5 (우)44705
# 532   532         돋질로   3.1      한정식      울산 남구 문수로327번길 14 (우)44645
# 533   533       행루즈버거   4.3      햄버거   울산 남구 월평로187번길 14 1층 (우)44696
# 534   534   등뼈가 울산달동점   4.6      감자탕           울산 남구 신정로 52 (우)44694
#
#                                         url
# 0     https://place.map.kakao.com/712292213
# 1      https://place.map.kakao.com/30184440
# ...

# %%
df.to_csv('ulsan_title.csv', index = False, encoding='utf-8-sig')
